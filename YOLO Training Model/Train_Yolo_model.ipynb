# %%
# !nvidia-smi
# Out:
# Sat Dec 13 13:46:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !git clone -b Rafawat https://github.com/rafawat2343/Smart-Road-Safety-Assistant.git
# Out:
# Cloning into 'Smart-Road-Safety-Assistant'...
# remote: Enumerating objects: 9577, done.
# remote: Counting objects: 100% (178/178), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 9577 (delta 152), reused 85 (delta 85), pack-reused 9399 (from 3)
# Receiving objects: 100% (9577/9577), 213.28 MiB | 39.11 MiB/s, done.
# Resolving deltas: 100% (2919/2919), done.
# Updating files: 100% (13117/13117), done.

# %%
# %cd /content/Smart-Road-Safety-Assistant/dataset_yolov8
# Out:
# [Errno 2] No such file or directory: '/content/Smart-Road-Safety-Assistant/dataset_yolov8'
# /content

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# %cd {HOME}
model = YOLO('/content/Smart-Road-Safety-Assistant/YOLO Training Model/yolov8n.pt')
# Out:
# /content

# %%
model.train(data ='/content/Smart-Road-Safety-Assistant/YOLO Training Model/dataset_yolov11/data.yaml', epochs =250, imgsz =640, batch =8, name = 'vehicles_detection_YOLO')
# Out:
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
import shutil
runs_path = f'{HOME}/runs'
shutil.make_archive(runs_path, 'zip', runs_path)
files.download(f'{runs_path}.zip')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r runs /content/drive/MyDrive/

# %%
# !cp -r dataset /content/drive/MyDrive/Cse299/
# Out:
# cp: cannot stat 'dataset': No such file or directory

# %%
from ultralytics import YOLO
model = YOLO('/content/runs/detect/vehicles_detection_YOLO/weights/best.pt')
metrics = model.val(data = '/content/Smart-Road-Safety-Assistant/dataset_yolov8/data.yaml', split = 'test')
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,009,743 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1273.6±354.0 MB/s, size: 66.2 KB)
# val: Scanning /content/Smart-Road-Safety-Assistant/dataset_yolov8/test/labels... 110 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 110/110 2.4Kit/s 0.0s
# val: New cache created: /content/Smart-Road-Safety-Assistant/dataset_yolov8/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.0s
#                    all        110        237      0.764      0.625      0.707      0.473
#          Auto-Rickshaw          1          1          1          0      0.497      0.398
#                Bicycle         14         21      0.897      0.762      0.815      0.427
# ...

# %%
print(metrics)
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([ 0,  1,  2,  3,  4,  5,  6,  8,  9, 11, 12, 13, 14, 15, 16, 18, 19, 20])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7ab72c0d4c20>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
# ...
